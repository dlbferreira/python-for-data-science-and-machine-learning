# %% [markdown]
# <a href="https://colab.research.google.com/github/dlbferreira/python-for-data-science-and-machine-learning/blob/main/plotly_cufflinks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Plotly And Cufflinks**

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
from plotly import __version__

# %%
print(__version__)
# Out:
# 4.4.1

# %%
import cufflinks as cf

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# DATA
df = pd.DataFrame(np.random.randn(100,4),columns='A B C D'.split())
df.head()
# Out:
#           A         B         C         D
# 0  0.009125  2.478025 -0.302852 -0.847122
# 1  0.348034  0.098244 -1.044679 -0.976201
# 2  0.723690  0.404545  0.631526 -0.919931
# 3 -0.144347  0.385131 -0.817281 -0.821916
# 4  0.162255  1.096619  2.779902  0.081506

# %%
df2 = pd.DataFrame({'Category':['A','B','C'],'Values':[32,43,50]})
df2.head()
# Out:
#   Category  Values
# 0        A      32
# 1        B      43
# 2        C      50

# %%
df.iplot()
# Out:
# <div>
#
#
#             <div id="6bb73daf-5f5f-4ce4-aa56-3f11cba7718b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6bb73daf-5f5f-4ce4-aa56-3f11cba7718b")) {
#                     Plotly.newPlot(
#                         '6bb73daf-5f5f-4ce4-aa56-3f11cba7718b',
# ...
