# %% [markdown]
# <a href="https://colab.research.google.com/github/dlbferreira/python-for-data-science-and-machine-learning/blob/main/pandas_built_in.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Pandas Bult-in Data Visualization**

# %%
import numpy as np

# %%
import seaborn as sns

# %%
import pandas as pd

# %%
# %matplotlib inline

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df1 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python-for-data-science-and-machine-learning/section-10-pandas-built-in-data-viz/df1',index_col=0)

# %%
df1 = df1.reset_index()

# %%
df1.head()
# Out:
#         index         A         B         C         D
# 0  2000-01-01  1.339091 -0.163643 -0.646443  1.041233
# 1  2000-01-02 -0.774984  0.137034 -0.882716 -2.253382
# 2  2000-01-03 -0.921037 -0.482943 -0.417100  0.478638
# 3  2000-01-04 -1.738808 -0.072973  0.056517  0.015085
# 4  2000-01-05 -0.905980  1.778576  0.381918  0.291436

# %%
df2 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python-for-data-science-and-machine-learning/section-10-pandas-built-in-data-viz/df2', index_col=0)

# %%
df2 = df2.reset_index()

# %%
df2.head()
# Out:
#           a         b         c         d
# 0  0.039762  0.218517  0.103423  0.957904
# 1  0.937288  0.041567  0.899125  0.977680
# 2  0.780504  0.008948  0.557808  0.797510
# 3  0.672717  0.247870  0.264071  0.444358
# 4  0.053829  0.520124  0.552264  0.190008

# %%
df3 = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/python-for-data-science-and-machine-learning/section-10-pandas-built-in-data-viz/df3', index_col=0)

# %%
df3 = df3.reset_index()

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df1['A'].hist(bins=30)

# %%
df1['A'].plot(kind='hist',bins=30)

# %%
df1['A'].plot.hist()

# %%
df2.plot.area(alpha=.4)

# %%
df2.plot.bar(stacked=True)

# %%
df1.plot.line(x='index',y='B')

# %%
df1.plot.scatter(x='A',y='B')

# %%
df1.plot.scatter(x='A',y='B',c='C',cmap='coolwarm')

# %%
df1.plot.scatter(x='A',y='B',s=df1['C']*100)
# Out:
# /usr/local/lib/python3.6/dist-packages/matplotlib/collections.py:885: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %%
df2.plot.box()

# %%
df = pd.DataFrame(np.random.randn(1000,2),columns=['a','b'])

# %%
df.plot.hexbin(x='a',y='b',gridsize=25)

# %%
df2['a'].plot.kde()

# %%
df2.plot.density()
