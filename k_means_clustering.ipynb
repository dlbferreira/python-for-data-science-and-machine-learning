# %% [markdown]
# <a href="https://colab.research.google.com/github/dlbferreira/python-for-data-science-and-machine-learning/blob/main/k_means_clustering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **K Means Clustering**

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.datasets import make_blobs

# %%
data = make_blobs(n_samples=200, n_features=2, centers=5, cluster_std=1.8,
                  random_state=101)

# %%
plt.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')

# %%
from sklearn.cluster import KMeans

# %%
kmeans = KMeans(n_clusters=8)

# %%
kmeans.fit(data[0])
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#        n_clusters=8, n_init=10, n_jobs=None, precompute_distances='auto',
#        random_state=None, tol=0.0001, verbose=0)

# %%
kmeans.cluster_centers_
# Out:
# array([[ -4.34619653,   8.3173437 ],
#        [  4.55432093,  -6.46191832],
#        [-10.81549034,  -4.92108966],
#        [  4.79433931,   4.4036686 ],
#        [  0.31163821,   4.39246092],
#        [ -0.22080249,   1.1316627 ],
#        [  3.42588767,   8.32846039],
#        [ -8.91745265,  -7.75560668]])

# %%
# predict labels
kmeans.labels_
# Out:
# array([6, 5, 1, 0, 1, 1, 1, 6, 0, 4, 5, 1, 2, 6, 6, 1, 5, 7, 4, 4, 4, 4,
#        5, 7, 7, 5, 4, 1, 7, 3, 5, 0, 3, 6, 4, 7, 5, 0, 4, 1, 4, 7, 2, 6,
#        4, 1, 6, 6, 3, 3, 2, 7, 1, 4, 1, 1, 2, 3, 7, 3, 4, 6, 1, 6, 6, 0,
#        1, 0, 6, 0, 7, 0, 1, 6, 3, 3, 5, 2, 1, 7, 0, 0, 5, 1, 5, 7, 0, 1,
#        6, 4, 0, 5, 5, 6, 1, 0, 2, 7, 0, 2, 6, 1, 5, 2, 0, 1, 2, 0, 5, 2,
#        4, 7, 0, 7, 3, 1, 3, 2, 4, 0, 1, 3, 6, 0, 1, 0, 0, 1, 5, 1, 5, 7,
#        1, 1, 1, 5, 3, 3, 1, 6, 0, 0, 0, 2, 7, 3, 7, 0, 1, 0, 5, 7, 1, 1,
#        1, 1, 5, 0, 7, 1, 4, 3, 0, 2, 6, 5, 5, 1, 2, 5, 4, 0, 0, 5, 0, 5,
#        1, 0, 4, 1, 0, 0, 4, 0, 1, 7, 7, 6, 7, 2, 7, 3, 7, 4, 6, 6, 0, 0,
#        2, 3], dtype=int32)

# %%
fig, (ax1,ax2) = plt.subplots(1,2, sharey=True, figsize=(10,6))

ax1.set_title('K Means')
ax1.scatter(data[0][:,0],data[0][:,1],c=kmeans.labels_,cmap='rainbow')

ax2.set_title('Original')
ax2.scatter(data[0][:,0],data[0][:,1],c=data[1],cmap='rainbow')
